# %%
import os
import pandas as pd
import shutil

# %%
# !nvidia-smi
# Out:
# Wed Feb  5 07:37:09 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17270, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 17270 (delta 0), reused 0 (delta 0), pack-reused 17269 (from 2)
# Receiving objects: 100% (17270/17270), 16.10 MiB | 19.21 MiB/s, done.
# Resolving deltas: 100% (11855/11855), done.

# %%
# !pip install -r yolov5/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 65.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 58.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# Extract the uploaded ZIP file
# !unzip -q GTSRB.zip -d /content/datasets/

# %%
# Train YOLOv5s on GTSRB for 2 epochs
# !python yolov5/train.py --img 640 --batch 64 --epochs 2 --data traffic.yaml --weights yolov5s.pt
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-02-05 03:12:44.728465: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738725164.751036    4600 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738725164.757474    4600 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# Train YOLOv5s on GTSRB for validation
# !python yolov5/val.py --img 640 --data traffic.yaml --weights yolov5/runs/train/exp3/weights/best_3.pt --conf 0.35
# Out:
# val: data=traffic.yaml, weights=['yolov5/runs/train/exp3/weights/best_3.pt'], batch_size=32, imgsz=640, conf_thres=0.35, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ confidence threshold 0.35 > 0.001 produces invalid results
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7126096 parameters, 0 gradients, 16.1 GFLOPs
# val: Scanning /content/dataset/GTSRB/labels/val.cache... 7842 images, 0 backgrounds, 0 corrupt: 100% 7842/7842 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 246/246 [01:12<00:00,  3.39it/s]
#                    all       7842       7842     0.0905     0.0644     0.0785     0.0485
# ...

# %%
# Train YOLOv5s on GTSRB for 15 epochs
# !python yolov5/train.py --img 640 --batch 64 --epochs 15 --data traffic.yaml --weights yolov5s.pt --cache disk
# Out:
# Streaming output truncated to the last 5000 lines.
#        9/14        12G     0.0153   0.007362    0.02945        183        640:  99% 487/491 [10:54<00:04,  1.10s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/14        12G    0.01529   0.007361    0.02942        166        640:  99% 488/491 [10:56<00:03,  1.18s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/14        12G    0.01528   0.007359    0.02939        149        640: 100% 489/491 [10:57<00:02,  1.08s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !python yolov5/val.py --img 640 --data traffic.yaml --weights yolov5/runs/train/exp/weights/best15.pt --conf 0.35
# Out:
# val: data=traffic.yaml, weights=['yolov5/runs/train/exp/weights/best15.pt'], batch_size=32, imgsz=640, conf_thres=0.35, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ confidence threshold 0.35 > 0.001 produces invalid results
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7126096 parameters, 0 gradients, 16.1 GFLOPs
# val: Scanning /content/datasets/GTSRB/labels/val.cache... 7842 images, 0 backgrounds, 0 corrupt: 100% 7842/7842 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 246/246 [01:43<00:00,  2.38it/s]
#                    all       7842       7842      0.935      0.951      0.947      0.891
# ...

# %%
# !python yolov5/val.py --img 640 --data traffic.yaml --weights yolov5/runs/train/exp/weights/last.pt --conf 0.35
# Out:
# val: data=traffic.yaml, weights=['yolov5/runs/train/exp/weights/last.pt'], batch_size=32, imgsz=640, conf_thres=0.35, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ confidence threshold 0.35 > 0.001 produces invalid results
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7126096 parameters, 0 gradients, 16.1 GFLOPs
# val: Scanning /content/datasets/GTSRB/labels/val.cache... 7842 images, 0 backgrounds, 0 corrupt: 100% 7842/7842 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 246/246 [01:45<00:00,  2.34it/s]
#                    all       7842       7842      0.935      0.951      0.947      0.891
# ...

# %%
# !ls
# Out:
# datasets  GTSRB.zip  sample_data  traffic.yaml	yolov5	yolov5s.pt

# %%
# !zip -r exp15.zip yolov5/runs/train/exp yolov5/runs/val/exp2
# Out:
#   adding: yolov5/runs/train/exp/ (stored 0%)
#   adding: yolov5/runs/train/exp/train_batch0.jpg (deflated 8%)
#   adding: yolov5/runs/train/exp/F1_curve.png (deflated 9%)
#   adding: yolov5/runs/train/exp/train_batch1.jpg (deflated 9%)
#   adding: yolov5/runs/train/exp/confusion_matrix.png (deflated 16%)
#   adding: yolov5/runs/train/exp/labels_correlogram.jpg (deflated 41%)
#   adding: yolov5/runs/train/exp/results.csv (deflated 81%)
#   adding: yolov5/runs/train/exp/val_batch1_pred.jpg (deflated 15%)
#   adding: yolov5/runs/train/exp/PR_curve.png (deflated 17%)
#   adding: yolov5/runs/train/exp/opt.yaml (deflated 50%)
#   adding: yolov5/runs/train/exp/labels.jpg (deflated 40%)
#   adding: yolov5/runs/train/exp/val_batch0_pred.jpg (deflated 16%)
#   adding: yolov5/runs/train/exp/weights/ (stored 0%)
#   adding: yolov5/runs/train/exp/weights/best15.pt (deflated 9%)
#   adding: yolov5/runs/train/exp/weights/last.pt (deflated 9%)
# ...

# %%
# !zip -r working/exp30.zip working/yolov5/runs/train/exp13 working/yolov5/runs/val/exp3 && cp /kaggle/working/exp30.zip /kaggle/working/
from IPython.display import FileLink
FileLink('working/exp30.zip')
